# %%
# !pip install qiskit --quiet
# !pip install qiskit-aer --quiet

# %%
# Task 1: Superposition
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt

# Create 1-qubit circuit
qc = QuantumCircuit(1, 1)
qc.h(0)           # Hadamard gate
qc.measure(0, 0)  # measure

# Simulate
sim = AerSimulator()
job = sim.run(qc, shots=1024)
result = job.result()
counts = result.get_counts()
print("Superposition Counts:", counts)

# Plot histogram
plot_histogram(counts)
plt.title("Superposition Measurement")
plt.show()
# Out:
# Superposition Counts: {'0': 494, '1': 530}

# %%
# Task 2: Entanglement
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt

# Create 2-qubit circuit
qc = QuantumCircuit(2, 2)
qc.h(0)           # Hadamard on qubit 0
qc.cx(0, 1)       # CNOT: control 0 -> target 1
qc.measure([0, 1], [0, 1])

# Simulate
sim = AerSimulator()
job = sim.run(qc, shots=1024)
result = job.result()
counts = result.get_counts()
print("Entanglement Counts:", counts)

# Plot histogram
plot_histogram(counts)
plt.title("Entanglement Measurement")
plt.show()
# Out:
# Entanglement Counts: {'00': 529, '11': 495}
